# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Netflix = pd.read_csv(r"C:\Users\Administrator\Downloads\netflix_cleaned.csv")

# %%
Netflix
# Out:
#                             Name    Year Age Rating Duration  \
# 0                  The Sea Beast  2022.0         7+   1h 59m
# 1             Sonic the Hedgehog  2020.0         7+   1h 41m
# 2                  Tom and Jerry  2021.0         7+   1h 41m
# 3               We Can Be Heroes  2020.0         7+   1h 40m
# 4         STAND BY ME Doraemon 2  2020.0         7+   1h 37m
# ...                          ...     ...        ...      ...
# 2724                         Mom  2017.0        16+   2h 18m
# 2725  The Legend of Bhagat Singh  2002.0        16+   2h 35m
# 2726                  Article 15  2019.0        16+    2h 5m
# 2727               We Are Family  2010.0        13+   1h 58m
# 2728             Ajeeb Daastaans  2021.0        18+   2h 22m
#
#                        Category
# 0          Kids & Family Movies
# 1          Kids & Family Movies
# 2          Kids & Family Movies
# 3          Kids & Family Movies
# 4          Kids & Family Movies
# ...                         ...
# ...

# %%
Netflix.head()
# Out:
#                      Name    Year Age Rating Duration              Category
# 0           The Sea Beast  2022.0         7+   1h 59m  Kids & Family Movies
# 1      Sonic the Hedgehog  2020.0         7+   1h 41m  Kids & Family Movies
# 2           Tom and Jerry  2021.0         7+   1h 41m  Kids & Family Movies
# 3        We Can Be Heroes  2020.0         7+   1h 40m  Kids & Family Movies
# 4  STAND BY ME Doraemon 2  2020.0         7+   1h 37m  Kids & Family Movies

# %%
Netflix.shape
# Out:
# (2729, 5)

# %%
Netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2729 entries, 0 to 2728
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        2729 non-null   object
#  1   Year        2729 non-null   float64
#  2   Age Rating  2729 non-null   object
#  3   Duration    2729 non-null   object
#  4   Category    2729 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 106.7+ KB

# %%
Netflix.describe()
# Out:
#               Year
# count  2729.000000
# mean   2014.920117
# std       8.299043
# min    1954.000000
# 25%    2012.000000
# 50%    2018.000000
# 75%    2020.000000
# max    2022.000000

# %%
Netflix.tail()
# Out:
#                             Name    Year Age Rating Duration  \
# 2724                         Mom  2017.0        16+   2h 18m
# 2725  The Legend of Bhagat Singh  2002.0        16+   2h 35m
# 2726                  Article 15  2019.0        16+    2h 5m
# 2727               We Are Family  2010.0        13+   1h 58m
# 2728             Ajeeb Daastaans  2021.0        18+   2h 22m
#
#                        Category
# 2724                     Dramas
# 2725  Movies Based on Real Life
# 2726                     Dramas
# 2727                     Dramas
# 2728                     Dramas

# %%
Netflix.isnull().sum()
# Out:
# Name          0
# Year          0
# Age Rating    0
# Duration      0
# Category      0
# dtype: int64

# %%
Netflix.duplicated().sum()
# Out:
# np.int64(0)

# %%
Netflix.dtypes
# Out:
# Name           object
# Year          float64
# Age Rating     object
# Duration       object
# Category       object
# dtype: object

# %%
sns.countplot(x="Age Rating", data=Netflix)
plt.show()

# %%
order = Netflix["Category"].value_counts().head(5).index
sns.countplot(y="Category", data=Netflix, order=order)
plt.show()

# %%
sns.countplot(x="Year", data=Netflix)
plt.show()

# %%
sns.relplot(x="Duration", y="Age Rating", data=Netflix)
plt.show()

# %%
sns.countplot(x="Year", data=Netflix)
plt.xticks(rotation=45)
plt.show()

# %%
sns.histplot(data=Netflix, x="Category")
plt.show()

# %%
sns.histplot(data=Netflix, y="fixed acidity")
plt.show()

# %%
sns.countplot(x="sulphates", data=Netflix)
plt.show()

# %%
sns.countplot(x="Category", hue="Age Rating", data=Netflix)
plt.show()

# %%
sns.boxplot(x="Age Rating", y="Year", data=Netflix)
plt.show()

# %%
sns.violinplot(y="Year", data=Netflix)
plt.show()

# %%
sns.pairplot(Netflix, hue="Age Rating")
plt.show()

# %%
sns.heatmap(Netflix.pivot_table(index="Age Rating", columns="Year", values="Name", aggfunc = "count", observed=False), annot=True)
plt.show()
