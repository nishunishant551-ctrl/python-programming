# %%
# Looping through python
#if , elif , else statements
#if = runs when if statement is true
#elif = runs when elif statement is true
#else = runs when both above statements are false
#Q1 Looping through Python: Control flow statements: if, else, elif. Looping constructs: for and while loops with examples. Use of break, continue, and pass statements in loops
# Control Flow statements
#example
# To check and assign the score
score=int(input("Enter the score"))
if score>90:
    print("Your grade is A")
elif score>75:
    print("Your grade is B")
else:
    print("Your grade is C")
# Out:
# Enter the score 53
# Your grade is C

# %%
#Looping constructs for and while loop
#For loop
for i in range(5):
    print("Number :",i)
# Out:
# Number : 0
# Number : 1
# Number : 2
# Number : 3
# Number : 4

# %%
fruits=["apple","cherry","banana"]
for fruits in fruits:
    print(fruits)
# Out:
# apple
# cherry
# banana

# %%
# While loop
count=0
while count<5:
    print("count:",count)
    count+=1
# Out:
# count: 0
# count: 1
# count: 2
# count: 3
# count: 4

# %%
# loop control statemts
for i in range(10):
    if i==5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# continue
for i in range (5):
    if i==2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
#pass
for i in range(3):
    if i==1:
        pass #do nothing
    else:
        print("number:",i)
# Out:
# number: 0
# number: 2
