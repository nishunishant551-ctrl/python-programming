# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ypoints = np.array([1,3,4,5])
plt.plot(ypoints,linestyle = "dotted")
plt.show()

# %%
y1 = np.array([1,9, 2,5])
y2 = np.array([4,6,8,3])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
y1 = np.array([4, 6, 9, 13])
plt.plot(y1,linewidth='.9')
plt.show()

# %%
y1 = np.array([10,1,7,19])
plt.plot(y1,color = "c")
plt.show()

# %%
x = np.array([60, 65, 70, 75, 80, 85, 90, 95, 100, 105])
y = np.array([180, 195, 210, 225, 240, 255, 270, 285, 300, 315])

plt.plot(x, y)

plt.xlabel("Heart Rate")
plt.ylabel("Calories Burned")

plt.show()

# %%
#first plot
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1,2,1)
plt.plot(x,y)

#second plot
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
x = np.array([4,6,9,6,1,16,3,4,5,10,11,8,5])
y = np.array([111,12,40,45,222,71,201,60,87,56,66,74,76])
plt.scatter(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([6, 9, 3, 14])
plt.bar(x,y)
plt.show()

# %%
tips= sns.load_dataset("Tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#sactterplot
sns.scatterplot(x="tip",y="total_bill",hue="sex",data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
tips.drop(["sex"],axis=1,inplace=True)

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
#sactterplot
sns.scatterplot(x="size",y="tip",hue="time",data=tips)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
tips.drop(["time"],axis=1,inplace=True)

# %%
tips
# Out:
#      total_bill   tip smoker   day  size
# 0         16.99  1.01     No   Sun     2
# 1         10.34  1.66     No   Sun     3
# 2         21.01  3.50     No   Sun     3
# 3         23.68  3.31     No   Sun     2
# 4         24.59  3.61     No   Sun     4
# ..          ...   ...    ...   ...   ...
# 239       29.03  5.92     No   Sat     3
# 240       27.18  2.00    Yes   Sat     2
# 241       22.67  2.00    Yes   Sat     2
# 242       17.82  1.75     No   Sat     2
# 243       18.78  3.00     No  Thur     2
#
# [244 rows x 5 columns]

# %%
#line plot
sns.lineplot(x="tip",y="size",data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='size'>

# %%
sns.relplot(x="tip",y="total_bill", hue="smoker",col="size",data=tips)

# %%
sns.histplot(tip["total_bill"],bins=25)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(tips["tip"],fill=True)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.histplot(tips["total_bill"],bins=30,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.boxplot(x="size",y="tip",data=tips)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.violinplot(x="size",y="tip",hue="smoker",split=True,data=tips)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.barplot(x="day",y="size",hue="day",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='size'>

# %%
sns.countplot(tips["smoker"])
# Out:
# <Axes: xlabel='count', ylabel='smoker'>
